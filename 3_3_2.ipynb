# %% [markdown]
# <a href="https://colab.research.google.com/github/BeatrixBlaine/DS-C1/blob/main/3_3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# MMLU Dataset
# Multi-domain Math & Logic Understanding

MMLU = [
    {
        "id": 1,
        "category": "arithmetic",
        "question": "What is 15 + 27?",
        "answer": "42",
        "difficulty": "easy"
    },
    {
        "id": 2,
        "category": "arithmetic",
        "question": "What is 8 × 6?",
        "answer": "48",
        "difficulty": "easy"
    },
    {
        "id": 3,
        "category": "arithmetic",
        "question": "What is 45 ÷ 5?",
        "answer": "9",
        "difficulty": "easy"
    },
    {
        "id": 4,
        "category": "logic",
        "question": "If all cats are animals and all animals breathe, do cats breathe?",
        "answer": "Yes",
        "difficulty": "easy"
    },
    {
        "id": 5,
        "category": "word_problem",
        "question": (
            "Tom has 12 candies. He gives 5 to his friend and buys 7 more. "
            "How many candies does Tom have now?"
        ),
        "answer": "14",
        "difficulty": "medium"
    },
    {
        "id": 6,
        "category": "pattern",
        "question": "What is the next number in the sequence: 2, 4, 8, 16, ?",
        "answer": "32",
        "difficulty": "easy"
    }
]

# %%
print(MMLU[0]["question"])
print("Answer:", MMLU[0]["answer"])
# Out:
# What is 15 + 27?
# Answer: 42
