# %% [markdown]
# <a href="https://colab.research.google.com/github/BeatrixBlaine/DS-C1/blob/main/3_3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# BigBench Dataset
# Broad, multi-task evaluation benchmark (toy version)

BigBench = [
    {
        "id": 1,
        "task": "arithmetic",
        "question": "What is 23 + 19?",
        "answer": "42",
        "difficulty": "easy"
    },
    {
        "id": 2,
        "task": "arithmetic",
        "question": "What is 7 × 8?",
        "answer": "56",
        "difficulty": "easy"
    },
    {
        "id": 3,
        "task": "logical_reasoning",
        "question": (
            "If all birds can fly and a sparrow is a bird, "
            "can a sparrow fly?"
        ),
        "answer": "Yes",
        "difficulty": "easy"
    },
    {
        "id": 4,
        "task": "commonsense",
        "question": (
            "If you put ice in the sun, what will most likely happen?"
        ),
        "answer": "It will melt",
        "difficulty": "easy"
    },
    {
        "id": 5,
        "task": "word_problem",
        "question": (
            "Anna has 10 books. She gives 3 away and buys 5 more. "
            "How many books does she have now?"
        ),
        "answer": "12",
        "difficulty": "medium"
    },
    {
        "id": 6,
        "task": "pattern_recognition",
        "question": (
            "What comes next in the sequence: A, C, E, G, ?"
        ),
        "answer": "I",
        "difficulty": "medium"
    }
]

# %%
for item in BigBench:
    print(item["task"], "→", item["question"])
# Out:
# arithmetic → What is 23 + 19?
# arithmetic → What is 7 × 8?
# logical_reasoning → If all birds can fly and a sparrow is a bird, can a sparrow fly?
# commonsense → If you put ice in the sun, what will most likely happen?
# word_problem → Anna has 10 books. She gives 3 away and buys 5 more. How many books does she have now?
# pattern_recognition → What comes next in the sequence: A, C, E, G, ?

# %%
def load_bigbench():
    return BigBench
